# %% [markdown]
# # CSE437: Data Science - Coding with Real World Data

# %% [markdown]
# ###Project Name: Behavior-Based Grade Prediction Time Series Neural Network
# * Dataset: https://www.kaggle.com/datasets/meirnizri/covid19-dataset
# *  Colab: https://colab.research.google.com/drive/1-gCBsp0ddPr37JHwyauci1JGk2kRxVw4#scrollTo=Bal6RnhEuyqW

# %% [markdown]
# **NOTE -** Restart the runtime and run all after running the following cell for the first time.

# %%
# !pip install matplotlib --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 76.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# ...

# %% [markdown]
# ## Import Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Data Visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Model Evaluation
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import RocCurveDisplay

#Model Training
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## Data Exploration

# %%
PATH =  "/content/drive/MyDrive/CSE437/covid-dataset.csv"

# %%
# COVID-19 Dataset

df = pd.read_csv(PATH)

print(f"ROWS: {round(df.shape[0] / 1000000, 2)} M \nCOLUMNS: {df.shape[1]}")
# Out:
# ROWS: 1.05 M
# COLUMNS: 21

# %%
df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
# ...

# %%
df.tail()
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 1048570          2   40        97         2  ...       2        2
# 1048571          2   51        97         2  ...       2        2
# 1048572          2   55        97         2  ...       2        2
# 1048573          2   28        97         2  ...       2        2
# 1048574          2   52        97         2  ...       2        2
#
#          HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
# ...

# %%
#checking null values in columns

df.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %% [markdown]
# It is clear that this dataset has no null values. But the dataset has one million rows, there must be some ambiguous data. Thus, we need to explore more.

# %%
#Unique values in columns

for i in df.columns:
    print(i, "==>", len(df[i].unique()))
# Out:
# USMER ==> 2
# MEDICAL_UNIT ==> 13
# SEX ==> 2
# PATIENT_TYPE ==> 2
# DATE_DIED ==> 401
# INTUBED ==> 4
# PNEUMONIA ==> 3
# AGE ==> 121
# PREGNANT ==> 4
# DIABETES ==> 3
# COPD ==> 3
# ASTHMA ==> 3
# INMSUPR ==> 3
# HIPERTENSION ==> 3
# OTHER_DISEASE ==> 3
# CARDIOVASCULAR ==> 3
# OBESITY ==> 3
# RENAL_CHRONIC ==> 3
# TOBACCO ==> 3
# CLASIFFICATION_FINAL ==> 7
# ICU ==> 4

# %% [markdown]
# ##Ambiguous Data
# We try to explore the data and look if there is any data that does not make any sense. They are marked for preprocessing and visualized.

# %%
#Death count based on dates

df.DATE_DIED.value_counts()
# Out:
# DATE_DIED
# 9999-99-99    971633
# 06/07/2020      1000
# 07/07/2020       996
# 13/07/2020       990
# 16/06/2020       979
#                ...
# 24/11/2020         1
# 17/12/2020         1
# 08/12/2020         1
# 16/03/2021         1
# 22/04/2021         1
# Name: count, Length: 401, dtype: int64

# %%
# Patients connected to ventilation

df.INTUBED.value_counts()
# Out:
# INTUBED
# 97    848544
# 2     159050
# 1      33656
# 99      7325
# Name: count, dtype: int64

# %%
#Patients in ICU

df.ICU.value_counts()
# Out:
# ICU
# 97    848544
# 2     175685
# 1      16858
# 99      7488
# Name: count, dtype: int64

# %%
#)atients with diabeties

df.DIABETES.value_counts()
# Out:
# DIABETES
# 2     920248
# 1     124989
# 98      3338
# Name: count, dtype: int64

# %% [markdown]
# Here, we know that a person can either have Diabetes (`1`) or not have Diabetes (`0`).
#
# Meaning, there is supposed to be only 2 values for `DIABETES`. Therefore, `98` represents Null value here.
#
# Same goes for `PNEUMONIA`, `COPD`, `ASTHMA`, etc.

# %%
#Patient with Pregnancy

df.PREGNANT.value_counts()
# Out:
# PREGNANT
# 97    523511
# 2     513179
# 1       8131
# 98      3754
# Name: count, dtype: int64

# %%
pd.crosstab(df.SEX, df.PREGNANT)
# Out:
# PREGNANT    1       2       97    98
# SEX
# 1         8131  513179       0  3754
# 2            0       0  523511     0

# %%
sns.countplot(x=df.SEX,
              hue = df.PREGNANT,
              palette="plasma")

plt.legend(loc='best')
plt.title("Pregnancy vs Sex", fontsize=20, color="orange");

# %% [markdown]
# In this case, male patients who are pregnant are represented by `97` of `PREGNANT`. We are aware that this is not possible.

# %% [markdown]
# # Data Preprocessing
#
# Now we can deal with ambiguous data and eliminate missing values. Depending on the situation, we may either modify the rows or remove them completely.

# %%
# Dealing with columns other than PREGNANT, DATE_DIED, ICU, INTUBED

df = df[(df.PNEUMONIA == 1) | (df.PNEUMONIA == 2)]
df = df[(df.DIABETES == 1) | (df.DIABETES == 2)]
df = df[(df.COPD == 1) | (df.COPD == 2)]
df = df[(df.ASTHMA == 1) | (df.ASTHMA == 2)]
df = df[(df.INMSUPR == 1) | (df.INMSUPR == 2)]
df = df[(df.HIPERTENSION == 1) | (df.HIPERTENSION == 2)]
df = df[(df.OTHER_DISEASE == 1) | (df.OTHER_DISEASE == 2)]
df = df[(df.CARDIOVASCULAR == 1) | (df.CARDIOVASCULAR == 2)]
df = df[(df.OBESITY == 1) | (df.OBESITY == 2)]
df = df[(df.RENAL_CHRONIC == 1) | (df.RENAL_CHRONIC == 2)]
df = df[(df.TOBACCO == 1) | (df.TOBACCO == 2)]

# %% [markdown]
# We only stored the rows here that had the values `1` and `2`. We dismissed all the others.

# %%
# Dealing with PREGNANT column

df.PREGNANT = df.PREGNANT.replace(97, 2)
df = df[(df.PREGNANT == 1) | (df.PREGNANT == 2)]

# %% [markdown]
# In this case, we changed the value `97` (male pregnant patients) to `2` (actual pregnant). And we let others go.

# %%
# Dealing with DATE_DIED column

df["DEATH"] = [2 if date == '9999-99-99' else 1 for date in df.DATE_DIED]
df.drop(columns=["DATE_DIED"], inplace=True)

# %% [markdown]
# In this case, a new column called `DEATH` is used to indicate if a patient is still alive.
#
# As a result, we eliminate the `DATE_DIED` column as it is unnecessary.

# %%
# Dealing with ICU column & INTUBED column

df.drop(columns=["ICU", "INTUBED"], inplace=True)

# %% [markdown]
# There are just too many ambiguous data points in the `ICU` and `INTUBED` columns to handle. As a result, we eliminate the `ICU` and `INTUBED` column as it is unnecessary.

# %% [markdown]
# # Data Visualization
# After addressing ambiguous and missing data, we attempt to display the dataset and its many columns to facilitate exploration and improve model building.

# %%
# Correlation Matrix

plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),
            annot=True,
            cmap="Oranges",
            fmt=".2f")

plt.title("Correlation Heatmap Between Features",
          fontsize=20,
          color="orange");

# %% [markdown]
# We can determine which features are more connected to one another using this correlation matrix. They are more correlated the darker color they are.
#
# ---

# %%
# Patients that are dead

ax = sns.countplot(x='DEATH',
                   data=df,
                   palette="plasma",
                   hue='DEATH')

plt.title("Death Distribution", fontsize=18, color="orange")

# Add labels to the bars
for container in ax.containers:
    ax.bar_label(container)

ax.set_xticks([0, 1])
ax.set_xticklabels(["Alive", "Dead"])
ax.legend().set_visible(False)

# %%
# Patients according to their ages

sns.histplot(x=df.AGE,
             color="orange")
plt.title("Age Distribution", color="orange", fontsize=20)
plt.xlabel("Age")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# We can see that most of the patients are between 20 to 60 years old.

# %%
# Relation between age & death


sns.boxplot(x="DEATH",
            y="AGE",
            data=df,
            color="orange")

plt.title("Death vs Age", fontsize=18, color="red")

# Set x-axis labels for better clarity
plt.xticks(ticks=[0, 1], labels=["Dead", "Alive"])

plt.show()

# %% [markdown]
# It seems that people between the ages of `30` and `70` have a greater chance of dying than those who are younger.

# %%
# Patients according to their sex

ax = sns.countplot(x="SEX",
                   data=df,
                   color="orange")

plt.title("Sex Distribution", fontsize=18, color="red")

for container in ax.containers:
    ax.bar_label(container)

plt.xticks(ticks=[0, 1], labels=["Female", "Male"])
plt.show()

# %%
# Death according to sex

ax = sns.countplot(x=df.SEX,
                   hue=df.DEATH,
                   palette="Oranges")

plt.title("Death vs Sex", fontsize=18, color="red")
plt.bar_label(ax.containers[0])
plt.bar_label(ax.containers[1])

plt.legend(["Dead", "Alive"], loc="best")
plt.xticks([0, 1], ["Female", "Male"]);

# %% [markdown]
# It is obvious that male patients have a higher mortality rate than female ones.

# %%
# Relation between death & obesity

ax = sns.countplot(x=df.OBESITY,
                   hue=df.DEATH,
                   palette="Oranges")

plt.title("Death vs Obesity", fontsize=18, color="red")
plt.bar_label(ax.containers[0])
plt.bar_label(ax.containers[1])

plt.legend(["Dead", "Alive"], loc="best")
plt.xticks([0, 1], ["Obese", "Fit"]);

# %% [markdown]
# It is obvious that fat patients have a higher death rate than fit patients.

# %%
# Relation between diabetes & hypertension

ax = sns.countplot(x=df.DIABETES,
                   hue=df.HIPERTENSION,
                   palette="Oranges")

plt.title("Diabetes vs Hypertension", fontsize=18, color="red")
plt.bar_label(ax.containers[0])
plt.bar_label(ax.containers[1])

plt.legend(["Hypertension", "No Hypertension"], loc="best")
plt.xticks([0, 1], ["Yes", "No"]);

# %% [markdown]
# It is obvious that those with diabetes also have a higher risk of hypertension.

# %% [markdown]
# ##Model Training

# %%
#independent variable
X = df.drop(columns="DEATH", axis=1)
#dependent variable
y = df["DEATH"]

# %%
# Split the data into train & test sets
np.random.seed(1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
models = {"LR": LogisticRegression(max_iter=1000),
          "KNN": KNeighborsClassifier(n_neighbors=6),
          "RF": RandomForestClassifier(),
          "DT": DecisionTreeClassifier(max_depth=1)}

def fit_and_score(models, X_train, X_test, y_train, y_test):
    np.random.seed(1)
    model_scores = {}
    for name, model in models.items():
        model.fit(X_train, y_train)
        model_scores[name] = model.score(X_test, y_test)

    return model_scores

# %%
model_scores = fit_and_score(models = models,
                             X_train = X_train,
                             X_test = X_test,
                             y_train = y_train,
                             y_test = y_test)
model_scores
# Out:
# {'LR': 0.9378852815123584,
#  'KNN': 0.9321170668701931,
#  'RF': 0.9342208262392611,
#  'DT': 0.9264662713556038}

# %% [markdown]
# **Model Scores -**
#
# * Logistic Regression: 0.9378852815123584
# * K-Nearest Neighbors: 0.9321170668701931
# * Random Forest: 0.9342208262392611
# * Decision Tree: 0.9264662713556038

# %%
model_compare = pd.DataFrame(model_scores, index=["accuracy"])
model_compare.T.plot.bar();

# %% [markdown]
# ###AdaBoost

# %%
adb_clf = AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1), n_estimators=100)
adb_clf.fit(X_train, y_train)
y_pred_proba = adb_clf.predict_proba(X_test)[:, 1]
adb_clf_roc_auc_score = roc_auc_score(y_test, y_pred_proba)

# %% [markdown]
# ###ROC Curve

# %%
print('ROC AUC score: {:.2f}'.format(adb_clf_roc_auc_score))
# Out:
# ROC AUC score: 0.96

# %%
RocCurveDisplay.from_estimator(adb_clf, X_test, y_test);

# %% [markdown]
# ###Confusion Matrix

# %%
import seaborn as sns

y_preds = adb_clf.predict(X_test)

fig, ax = plt.subplots(figsize=(3, 3))
ax = sns.heatmap(confusion_matrix(y_test, y_preds),
                annot=True,
                cbar=False)
plt.xlabel("Truth")
plt.ylabel("Prediction")
# Out:
# Text(8.222222222222223, 0.5, 'Prediction')

# %%
clf = adb_clf

# %% [markdown]
# ### Cross Validation
# `Accuracy` indicates the total number of times the ML model was accurate.
# The model's `precision` refers to how well it predicts a certain category.
# `Recall` indicates the number of times a certain category might be identified by the model.
# The `F1 Score` represents the harmonic mean of recall and accuracy.

# %%
# Cross-validated Accuracy

cv_accuracy = cross_val_score(clf, X, y,
                        cv=5,
                        scoring="accuracy")
cv_accuracy = np.mean(cv_accuracy)
cv_accuracy
# Out:
# 0.8763368828963163

# %%
# Cross-validated Precision

cv_precision = cross_val_score(clf, X, y,
                        cv=5,
                        scoring="precision")
cv_precision = np.mean(cv_precision)
cv_precision
# Out:
# 0.5252307598397844

# %%
# Cross-validated Recall

cv_recall = cross_val_score(clf, X, y,
                        cv=5,
                        scoring="recall")
cv_recall = np.mean(cv_recall)
cv_recall
# Out:
# 0.430026401651185

# %%
# Cross-validated F1

cv_f1 = cross_val_score(clf, X, y,
                        cv=5,
                        scoring="f1")
cv_f1 = np.mean(cv_f1)
cv_f1
# Out:
# 0.3176187711181153

# %%
cv_metrics = pd.DataFrame({"Accuracy": cv_accuracy,
                           "Precision": cv_precision,
                           "Recall": cv_recall,
                           "F1": cv_f1},
                           index=[0])

cv_metrics.T.plot.bar(title="Cross-validated Classification Metrics",
                      legend=False);
